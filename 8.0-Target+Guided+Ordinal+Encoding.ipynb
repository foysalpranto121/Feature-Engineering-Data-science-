# %% [markdown]
# ## Target Guided Ordinal Encoding
# It is a technique used to encode categorical variables based on their relationship with the target variable. This encoding technique is useful when we have a categorical variable with a large number of unique categories, and we want to use this variable as a feature in our machine learning model.
#
# In Target Guided Ordinal Encoding, we replace each category in the categorical variable with a numerical value based on the mean or median of the target variable for that category. This creates a monotonic relationship between the categorical variable and the target variable, which can improve the predictive power of our model.

# %% [markdown]
# Target Guided Ordinal Encoding এমন একটি কৌশল, যেখানে কোনো categorical (বর্ণনামূলক) ভেরিয়েবলকে তার target variable–এর সাথে সম্পর্ক অনুযায়ী সংখ্যা (ordinal values) দিয়ে এনকোড করা হয়।
#
# 🔍 এটি কেন দরকার?
#
# যখন কোনো ক্যাটেগরির সংখ্যা খুব বেশি হয় (যেমন শহরের নাম, প্রোডাক্ট টাইপ ইত্যাদি), তখন সেগুলিকে সরাসরি মডেলে ব্যবহার করলে সমস্যা হয়।
# এই এনকোডিং কৌশল ক্যাটেগরিগুলোর target-এর mean বা median ব্যবহার করে একটি ক্রমিক (ordered) সংখ্যায় রূপান্তর করে।
#
# ✨ কীভাবে কাজ করে?
#
# প্রতিটি ক্যাটেগরির জন্য target variable–এর mean বা median হিসাব করা হয়।
#
# mean/median মান অনুযায়ী প্রতিটি ক্যাটেগরিকে ক্রম (order) দিয়ে একটি সংখ্যা (0, 1, 2, …) দেওয়া হয়।
#
# এতে ক্যাটেগরি ও target–এর মধ্যে monotonic relationship তৈরি হয় (target বাড়লে encoded value–ও বাড়ে)।
#
# ফলে মডেল লক্ষ্য (target) ভেরিয়েবলের সাথে সম্পর্কটি ভালোভাবে শিখতে পারে।

# %%
import pandas as pd

# create a sample dataframe with a categorical variable and a target variable
df = pd.DataFrame({
    'city': ['New York', 'London', 'Paris', 'Tokyo', 'New York', 'Paris'],
    'price': [200, 150, 300, 250, 180, 320]
})

# %%
df
# Out:
#        city  price
# 0  New York    200
# 1    London    150
# 2     Paris    300
# 3     Tokyo    250
# 4  New York    180
# 5     Paris    320

# %%
mean_price=df.groupby('city')['price'].mean().to_dict()

# %%
mean_price
# Out:
# {'London': 150.0, 'New York': 190.0, 'Paris': 310.0, 'Tokyo': 250.0}

# %%
df['city_encoded']=df['city'].map(mean_price)

# %%
df[['price','city_encoded']]
# Out:
#    price  city_encoded
# 0    200         190.0
# 1    150         150.0
# 2    300         310.0
# 3    250         250.0
# 4    180         190.0
# 5    320         310.0

# %%
df
# Out:
#        city  price  city_encoded
# 0  New York    200         190.0
# 1    London    150         150.0
# 2     Paris    300         310.0
# 3     Tokyo    250         250.0
# 4  New York    180         190.0
# 5     Paris    320         310.0

# %%
import seaborn as sns
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
